# %%
# Importing the necessary libraries.
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import warnings
import seaborn as sns
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')

# %%
# Reading a CSV file
data = pd.read_csv('heart.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Features of dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# Check rows and colums in our dataset
data.shape
# Out:
# (303, 14)

# %%
# Check for NULL values
data.isnull().sum()
# There are no null values present in our dataset
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
# Count tell us how many non-empty rows in features
# mean tell us mean of each feature
# std tell us standard deviation of features
# min tell us what is the minimum value in respective feature
# 25%, 50%, and 75% are the percentile/quartile of each features.
# max tells us the maximum value of that feature.

# %%
# Checking features in our dataset
plt.figure(figsize=(7,8))
plt.pie([len(data[data['sex'] == 1]),len(data[data['sex'] == 0])],
        autopct='%1.1f',
        shadow=True,
        labels=None,
        colors=['yellowgreen','gold'],
        explode=[0.1,0],
        startangle=90
        );
plt.title("Pie chart for sex feature");
plt.legend(['male','female']);

# %%
# Inference:
# From above chart we can say that the  percentage of heart male patients is more than female

# %%
# Chest pain type
plt.figure(figsize=(7,8))
plt.pie([
        len(data[data['cp']==0]),
        len(data[data['cp']==1]),
        len(data[data['cp']==2]),
        len(data[data['cp']==3])
        ],
        startangle=180,
        autopct='%1.1f',
        labels=['type0','type1','type2','type3'],
        shadow=True,
        colors=['aquamarine','deepskyblue','greenyellow','lightcoral']
       );
plt.title('Chest pain types percenage');

# %%
# Inference:
#Chest pain type 0 have more percentage followed by type 2,type 1 and type 3

# %%
# exang: exercise induced angina (1 = yes; 0 = no)
plt.figure(figsize=(7,8))
plt.pie([
        len(data[data['exang']==0]),
        len(data[data['exang']==1])
        ],
        startangle=120,
        shadow=True,
        explode=[0.1,0],
        colors=['orange','lime'],
        labels=['Yes','No'],
        autopct='%1.1f'
        );
plt.title('Pie chart for exercise induced angina',{'fontsize':25});

# %%
plt.figure(figsize=(14,8))
sns.heatmap(data.corr(), annot = True, cmap='coolwarm',linewidths=.1)
plt.show()

# %%
sns.distplot(data.thalach,kde=False,color='magenta',bins=40);
plt.ylabel('Number of Counts');
plt.title("Distribution plot for Heart Rate",{'fontsize':25});

# %%
# Inference:
# Maximum heart rate is 160 and its count is near to 25 counts.

# %%
#chol: serum cholestoral in mg/dl 
sns.distplot(data.chol,kde=False,color='blue');
plt.ylabel('Number of Counts')
plt.title("distibution plot for Cholestrol",{'fontsize':25});

# %%
#trestbps: resting blood pressure (in mm Hg on admission to the hospital)
sns.distplot(data.trestbps,kde=False,color='crimson');
plt.ylabel('Number of Counts')
plt.title("distibution plot for Resting blood pressure",{'fontsize':25});

# %%
# Inference:
# The ideal blodd pressure is between 90 to 120 mm/hg but from above we can say that there are more people have blodd pressure more than 120

# %%
age_df  = data.groupby('age')['target'].sum().reset_index()

# %%
plt.figure(figsize=(10,10))
plt.bar(age_df.age,age_df.target,color='mediumblue');
plt.xlabel('Age')
plt.ylabel('Count');
plt.title('Number of people have heart desease based on age',{'fontsize':20});

# %%
# Inference:
# People over the age of 55 and 41 have the heart disease.

# %%
X = data.drop('target',axis=1)   # Dependent feature
y = data.target  # independent feature

# %%
# To get a good prediction, divide the data into training and testing data, it is because as the name suggests you will train few data points and test few data points, and keep on doing that unless you get good results.
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42) # Setting random_state a fixed value will guarantee that same sequence of random numbers are generated each time you run the code

# %%
data.shape
# Out:
# (303, 14)

# %%
len(X_train)
# Out:
# 212

# %%
len(X_test)
# Out:
# 91

# %%
# Preprocessing -Scaling features 
#The idea behind StandardScaler is that it will transform your data such that its distribution will have a mean value 0 and standard deviation of 1. 
from sklearn.preprocessing import StandardScaler
std_scalar = StandardScaler()
X_train_scaled = std_scalar.fit_transform(X_train)
X_train = pd.DataFrame(X_train_scaled)

X_test_scaled = std_scalar.fit_transform(X_test)
X_test = pd.DataFrame(X_test_scaled)

# %%
# k-Nearest Neighor Algorithm
from sklearn.neighbors import KNeighborsClassifier

# %%
# K parameter specifies how many neighbors to consider 
# To choose K we plot errr rate of our model

# %%
error_rate = []
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))
plt.plot(range(1,40),error_rate,marker='o')

# %%
# After plotting error rate we can observe that the minima is near to 6 
# so we can choose k-6 for our model

# %%
# Now we find K which is best for our model then train model with k=6
kneighbor = KNeighborsClassifier(n_neighbors=6)
kneighbor.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
y_pred = kneighbor.predict(X_test)

# %%
# Check accuracy score
print("Accuracy Score for KNeighborsClassifier : ",kneighbor.score(X_test,y_test)*100)
# Out:
# Accuracy Score for KNeighborsClassifier :  87.91208791208791

# %%
# Confusion metrix
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(y_test,y_pred)

# %%
class_names = [0,1]
fig,ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks,class_names)
plt.yticks(tick_marks,class_names)

#create a heat map
sns.heatmap(pd.DataFrame(cnf_matrix), annot = True, cmap = 'YlGnBu',
           fmt = 'g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion matrix for k-Nearest Neighbors Model', {'fontsize':20})
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.show()

# %%
# Classifiaction Report
from sklearn.metrics import classification_report
print(classification_report( y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87        41
#            1       0.90      0.88      0.89        50
#
#     accuracy                           0.88        91
#    macro avg       0.88      0.88      0.88        91
# weighted avg       0.88      0.88      0.88        91

# %%
labels = {1:'yes',0:'No'}

# %%
labels[kneighbor.predict([['63','1','3'	,'145'	,'233'	,'1',	'0',	'150',	'0'	,'2.3',	'0'	,'0',	'1'	]])[0]]
# Out:
# 'yes'

# %%
import pickle
with open('heartmodel.sav','wb') as f:
    pickle.dump(kneighbor,f)
